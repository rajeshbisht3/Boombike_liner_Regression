# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
pwd
# Out:
# 'C:\\Users\\rbisht'

# %%
dataset_df = pd.read_csv ('day.csv')

# %%
dataset_df.shape
# Out:
# (730, 16)

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
dataset_df.size
# Out:
# 11680

# %%
dataset_df.size
# Out:
# 11680

# %%
dataset_df.describe
# Out:
# <bound method NDFrame.describe of      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
# ...

# %%
dataset_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
## Data Cleaning 
##Instance and Date can be removed

dataset_df.drop(['instant'],)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7548\3305623860.py in <module>
#       2 ##Instance and Date can be removed
#       3
# ----> 4 dataset_df.drop(['instant'],)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
dataset_df.drop(['instant'],axis=1, inplace=True)

# %%
dataset_df.drop(['dteday'],axis=1, inplace=True)

# %%
dataset_df.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     2.498630    0.500000    6.526027    0.028767    2.997260    0.683562
# std      1.110184    0.500343    3.450215    0.167266    2.006161    0.465405
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    0.500000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.544807    7.506729    8.150308   14.237589    5.195841
# ...

# %%
dataset_df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed  casual  registered   cnt
# 0  18.18125  80.5833  10.749882     331         654   985
# 1  17.68695  69.6087  16.652113     131         670   801
# 2   9.47025  43.7273  16.636703     120        1229  1349
# 3  10.60610  59.0435  10.739832     108        1454  1562
# 4  11.46350  43.6957  12.522300      82        1518  1600

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  casual      730 non-null    int64
#  12  registered  730 non-null    int64
#  13  cnt         730 non-null    int64
# dtypes: float64(4), int64(10)
# memory usage: 80.0 KB

# %%
dataset_df.corr()
# Out:
#                   season            yr          mnth   holiday   weekday  \
# season      1.000000e+00 -3.279074e-16  8.310321e-01 -0.010868 -0.003081
# yr         -3.279074e-16  1.000000e+00 -5.162656e-16  0.008195 -0.005466
# mnth        8.310321e-01 -5.162656e-16  1.000000e+00  0.018905  0.009523
# holiday    -1.086804e-02  8.195345e-03  1.890483e-02  1.000000 -0.101962
# weekday    -3.081198e-03 -5.466369e-03  9.522969e-03 -0.101962  1.000000
# workingday  1.376178e-02 -2.945396e-03 -4.687953e-03 -0.252948  0.035800
# weathersit  2.130636e-02 -5.032247e-02  4.561335e-02 -0.034395  0.031112
# temp        3.333607e-01  4.878919e-02  2.190833e-01 -0.028764 -0.000168
# atemp       3.420139e-01  4.721519e-02  2.264302e-01 -0.032703 -0.007539
# hum         2.082196e-01 -1.125471e-01  2.249368e-01 -0.015662 -0.052290
# windspeed  -2.296069e-01 -1.162435e-02 -2.080131e-01  0.006257  0.014283
# casual      2.087373e-01  2.505017e-01  1.212079e-01  0.054055  0.059978
# ...

# %%
## Mising value

# %%
dataset_df.isnull()
# Out:
#      season     yr   mnth  holiday  weekday  workingday  weathersit   temp  \
# 0     False  False  False    False    False       False       False  False
# 1     False  False  False    False    False       False       False  False
# 2     False  False  False    False    False       False       False  False
# 3     False  False  False    False    False       False       False  False
# 4     False  False  False    False    False       False       False  False
# ..      ...    ...    ...      ...      ...         ...         ...    ...
# 725   False  False  False    False    False       False       False  False
# 726   False  False  False    False    False       False       False  False
# 727   False  False  False    False    False       False       False  False
# 728   False  False  False    False    False       False       False  False
# 729   False  False  False    False    False       False       False  False
#
#      atemp    hum  windspeed  casual  registered    cnt
# ...

# %%
dataset_df.isnull().sum()
# Out:
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
## Outliers check

# %%
cols = ['temp', 'atemp', 'hum', 'windspeed']
plt.figure(figsize=(18,4))

i = 1
for col in cols:
    plt.subplot(1,4,i)
    sns.boxplot(y=col, data=dataset_df)
    i+=1

# %%
### Linear Relationship

# %%
# s using seaborn
plt.figure(figsize = (15,30))
sns.pairplot(data=dataset_df,vars=['cnt', 'temp', 'atemp', 'hum','windspeed'])
plt.show()

# %%
# From above case Temperature and atemp is having higest corellation 
#Linear Relationship is avaiable for variables like temp and atemp

# %%
# Heat map

# %%
corr = dataset_df.corr()
plt.figure(figsize=(25,10))

#Draw Heatmap of correlation
sns.heatmap(corr,annot=True, cmap='YlGnBu' )
plt.show()

# %%
# COrelation between Temp and atemp is nearly 1 . So only one can be considered .

# %%
dataset_df.columns
# Out:
# Index(['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
dataset_df.shape
# Out:
# (730, 14)

# %%
#Import more libraries

# %%
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler

# %%
vars_cat = ['season','yr','mnth','holiday','weekday','workingday','weathersit']
plt.figure(figsize=(15, 15))
for i in enumerate(vars_cat):
    plt.subplot(3,3,i[0]+1)
    sns.boxplot(data=dataset_df, x=i[1], y='cnt')
plt.show()

# %%
#Season 3 has the highest growth 
#Growth is seen in following year 
#Demand growing till 9th month 
# demand decreases on holidays

# %%
dataset_df.head
# Out:
# <bound method NDFrame.head of      season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0         1   0     1        0        6           0           2  14.110847
# 1         1   0     1        0        0           0           2  14.902598
# 2         1   0     1        0        1           1           1   8.050924
# 3         1   0     1        0        2           1           1   8.200000
# 4         1   0     1        0        3           1           1   9.305237
# ..      ...  ..   ...      ...      ...         ...         ...        ...
# 725       1   1    12        0        4           1           2  10.420847
# 726       1   1    12        0        5           1           2  10.386653
# 727       1   1    12        0        6           0           2  10.386653
# 728       1   1    12        0        0           0           1  10.489153
# 729       1   1    12        0        1           1           2   8.849153
#
# ...

# %%
dataset_df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed  casual  registered   cnt
# 0  18.18125  80.5833  10.749882     331         654   985
# 1  17.68695  69.6087  16.652113     131         670   801
# 2   9.47025  43.7273  16.636703     120        1229  1349
# 3  10.60610  59.0435  10.739832     108        1454  1562
# 4  11.46350  43.6957  12.522300      82        1518  1600

# %%
#Pairwise Scatter Plot
sns.pairplot(dataset_df_numeric)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7548\1182719856.py in <module>
#       1 #Pairwise Scatter Plot
# ----> 2 sns.pairplot(dataset_df_numeric)
#       3 plt.show()
#
# NameError: name 'dataset_df_numeric' is not defined

# %%
bike_data = dataset_df.select_dtypes(include=['float64'])

# %%
bike_data.head()
# Out:
#         temp     atemp      hum  windspeed
# 0  14.110847  18.18125  80.5833  10.749882
# 1  14.902598  17.68695  69.6087  16.652113
# 2   8.050924   9.47025  43.7273  16.636703
# 3   8.200000  10.60610  59.0435  10.739832
# 4   9.305237  11.46350  43.6957  12.522300

# %%
sns.pairplot(bike_data)
plt.show()

# %% [markdown]
# # Data Prepration

# %%
#convert all values in integer in dummies

# %%
bike_cat= dataset_df.select_dtypes(include=['object'])

# %%
bike_inter = pd.get_dummies(bike_cat,drop_first=True)
bike_inter.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7548\3036604761.py in <module>
# ----> 1 bike_inter = pd.get_dummies(bike_cat,drop_first=True)
#       2 bike_inter.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     985             )
#     986             with_dummies.append(dummy)
# --> 987         result = concat(with_dummies, axis=1)
#     988     else:
#     989         result = _get_dummies_1d(
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
dataset_df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed  casual  registered   cnt
# 0  18.18125  80.5833  10.749882     331         654   985
# 1  17.68695  69.6087  16.652113     131         670   801
# 2   9.47025  43.7273  16.636703     120        1229  1349
# 3  10.60610  59.0435  10.739832     108        1454  1562
# 4  11.46350  43.6957  12.522300      82        1518  1600

# %%
#Split the dataframe into train and test sets
from sklearn.model_selection import train_test_split
np.random.seed(0)
df_train, df_test = train_test_split(dataset_df, train_size=0.7, test_size=0.3, random_state=100)

# %%
df_train
# Out:
#      season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 653       4   1    10        0        2           1           1  19.201653
# 576       3   1     7        0        2           1           1  29.246653
# 426       1   1     3        0        6           0           2  16.980847
# 728       1   1    12        0        0           0           1  10.489153
# 482       2   1     4        0        6           0           2  15.443347
# ..      ...  ..   ...      ...      ...         ...         ...        ...
# 526       2   1     6        0        1           1           2  29.554153
# 578       3   1     8        0        4           1           1  30.852500
# 53        1   0     2        0        3           1           1   9.091299
# 350       4   0    12        0        6           0           2  10.591653
# 79        2   0     3        0        1           1           2  17.647835
#
#         atemp      hum  windspeed  casual  registered   cnt
# ...

# %%
sns.distplot(dataset_df.temp)
# Out:
# C:\Users\rbisht\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='temp', ylabel='Density'>

# %%
sns.distplot(dataset_df.atemp)
# Out:
# C:\Users\rbisht\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='atemp', ylabel='Density'>

# %%
dataset_df['cnt'] = dataset_df['cnt'].astype(float)

# %%
IntVariableList = ['temp','atemp','hum','windspeed','cnt']

for var in IntVariableList:
   dataset_df[var] = dataset_df[var].astype('float')

# %%
#Importing important libraries 

from sklearn.model_selection import train_test_split

np.random.seed(0)
df_train, df_test = train_test_split(dataset_df, train_size = 0.8, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
num_vars=['temp','hum','windspeed','cnt']

df_train[num_vars]= scaler.fit_transform(df_train[num_vars])
df_test[num_vars]= scaler.transform(df_test[num_vars])

# %%
y_train = df_train.pop('cnt')
X_train = df_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14840\756474757.py in <module>
# ----> 1 y_train = df_train.pop('cnt')
#       2 X_train = df_train
#
# NameError: name 'df_train' is not defined
